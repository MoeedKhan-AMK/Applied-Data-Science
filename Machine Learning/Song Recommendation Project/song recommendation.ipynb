# %% [markdown]
# ## Song recommendation system

# %%
import pandas as pd
import json

# %%
songs = pd.read_csv("./songs.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 songs = pd.read_csv("./songs.csv")
#
# NameError: name 'pd' is not defined
