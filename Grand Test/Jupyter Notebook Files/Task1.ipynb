# %% [markdown]
# ## Grand Test

# %% [markdown]
# **Task 1**
#
# Data = students = [ [“Name”, “Marks”], ["Ali", 85], ["Sara", 42], ["Ahmed", 45], ["Zain", 40], ["Ayesha",
# 61], ["Ayaan", 80], ["Danial", 71], ["Aliza", 50], ["Danish", 91], ["Hamza", 68], ["Fatima", 77],
# ["Usman", 59], ["Bilal", 88], ["Hina", 73], ["Noor", 95], ["Maham", 66], ["Saad", 54], ["Iqra", 82],
# ["Laiba", 47], ["Kashif", 79], ["Amna", 62], ["Umer", 35], ["Yasir", 84], ["Anaya", 58], ["Rehan",
# 93], ["Sana", 69], ["Farhan", 75], ["Areeba", 81], ["Hasan", 49], ["Muneeb", 87] ]
#
# 1. Using a for loop and if-else statements, display each student's:
# - Name
# - Marks
# - Grade according to:
#     - A: 80+
#     - B: 70–79
#     - C: 60–69
#     - F: Below 60
# 2. Finally, print how many students passed and how many failed using frequency table.
