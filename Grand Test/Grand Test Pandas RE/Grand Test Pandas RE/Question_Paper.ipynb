# %% [markdown]
# **Applied Data Science & AI**
#
# ---
#
# | | |
# |---|---|
# | **Time allowed** | 1 hour 30 minutes |
# | **Total marks** | 100 |
#
# ---
#
# ### The scenario
#
# You have been handed the raw sales records of a laptop distributor operating across six
# cities in Pakistan. The six CSV files were exported from different systems, at different
# times, by different people. Nothing has been cleaned.
#
# ### The files
#
# | File | What it holds |
# |---|---|
# | `transactions_2023.csv` | Orders placed during 2023 |
# | `transactions_2024.csv` | Orders placed during 2024 - **exported from a different system** |
# | `customers.csv` | The customer register |
# | `products.csv` | The product catalogue |
# | `regions.csv` | Region code lookup |
# | `returns.csv` | Orders that came back |
#
#
# ### Rules
#
# 1. Work in pandas. Every answer must be code that runs.
# 2. Answer in order - later questions depend on DataFrames built in earlier ones.
# 3. Where a question asks you to explain something, write it as a comment in your code cell.
#
# ---

# %% [markdown]
# ## Part A - Reading and Inspecting
#
# *8 marks*
#
# Nothing needs cleaning yet. Find out what you are holding.

# %% [markdown]
# ### Question A1
# *4 marks - Medium*
#
# Load all six CSV files and report the shape of each.
#
# Then, for `transactions_2023`, state **which columns contain missing values and how many are missing in each**.

# %%
import pandas as pd
import re

# %%
customers = pd.read_csv("./customers.csv")
products = pd.read_csv("./products.csv")
regions = pd.read_csv("./regions.csv")
returns = pd.read_csv("./returns.csv")
transactions23 = pd.read_csv("./transactions_2023.csv")
transactions24 = pd.read_csv("./transactions_2024.csv")

# %%
customers.shape,products.shape,regions.shape,returns.shape,transactions23.shape,transactions24.shape
# Out:
# ((262, 5), (64, 5), (10, 4), (540, 3), (1400, 10), (1700, 10))

# %%
transactions23.head(3)
# Out:
#       Order ID             Customer Code Product ID       Qty      Sales Rep  \
# 0  ORD23-70001              CUST-PK-1221    PRD-871  17 units  Omar Siddiqui
# 1  ORD23-70002              cust_pk_1239    PRD-864   3 units            NaN
# 2  ORD23-70003  Customer: PK-1178 (2022)    PRD-864  19 units            NaN
#
#    Warehouse Discount % Order Month                       Order Note  \
# 0  WH-HYD-11         0%         Jun     [RUSH] deliver before friday
# 1  WH/ISB/12        NaN         Jul  [URGENT] client waiting at site
# 2  wh-skt-12       7.5%         Aug  [HOLD] awaiting credit approval
#
#                                     Source URL
# 0  https://portal.techmazone.com.pk/orders/new
# 1            http://b2b.dell-partners.pk/quote
# 2             https://shop.hpstore.pk/checkout

# %%
transactions23.columns
# Out:
# Index(['Order ID', 'Customer Code', 'Product ID', 'Qty', 'Sales Rep',
#        'Warehouse', 'Discount %', 'Order Month', 'Order Note', 'Source URL'],
#       dtype='object')

# %%
transactions23.isnull().sum()
# Out:
# Order ID            0
# Customer Code       0
# Product ID          0
# Qty                 0
# Sales Rep        1212
# Warehouse           0
# Discount %        144
# Order Month         0
# Order Note          0
# Source URL          0
# dtype: int64

# %% [markdown]
# - There are only Two columns **Sales Rep** & **Discount %** with missing values.
# - Number of `Missing Values` in each Column: `Sales Rep : 1212, Discount % : 144`

# %% [markdown]
# ### Question A2
# *4 marks - Medium*
#
# Three short parts on `products` and `transactions_2023`, before any cleaning:
#
# 1. Return the first 5 rows and first 3 columns of `products` by **position**.
# 2. Return rows labelled 10 to 15 of `products` with the columns from `Product Details` to `Unit Price`, by **label**.
# 3. How many 2023 orders were placed at exactly a 15% discount?
#
# In a comment, state how many rows part 2 returned and why it is not the same count as `iloc[10:15]`.

# %%
products.iloc[0:5,0:3]
# Out:
#   Product ID              Product Details   Category
# 0    PRD-507  Dell Latitude 5420 15.6inch     Laptop
# 1    PRD-514  Dell Latitude 7430 16.0inch    laptop
# 2    PRD-521    Dell Vostro 3510 17.3inch     LAPTOP
# 3    PRD-528    Dell Vostro 5620 13.3inch     Laptop
# 4    PRD-535  Dell Inspiron 3511 14.0inch  Ultrabook

# %%
products
# Out:
#    Product ID                  Product Details      Category   Unit Price  \
# 0     PRD-507      Dell Latitude 5420 15.6inch        Laptop  PKR 325,000
# 1     PRD-514      Dell Latitude 7430 16.0inch       laptop   PKR 364,000
# 2     PRD-521        Dell Vostro 3510 17.3inch        LAPTOP  PKR 410,000
# 3     PRD-528        Dell Vostro 5620 13.3inch        Laptop   PKR 72,000
# 4     PRD-535      Dell Inspiron 3511 14.0inch     Ultrabook   PKR 85,000
# ..        ...                              ...           ...          ...
# 59    PRD-920    Samsung Galaxy Book2 14.0inch  workstation   PKR 298,000
# 60    PRD-927    Samsung Galaxy Book3 15.6inch        Laptop  PKR 325,000
# 61    PRD-934  Samsung Notebook Flash 16.0inch       laptop   PKR 364,000
# 62    PRD-941      Samsung Odyssey 15 17.3inch        LAPTOP  PKR 410,000
# 63    PRD-948    Samsung Galaxy Book4 13.3inch        Laptop   PKR 72,000
#
#     Warranty (Months)
# 0                36.0
# 1                12.0
# 2                24.0
# 3                12.0
# 4                12.0
# ..                ...
# 59               24.0
# 60               24.0
# 61               24.0
# 62               24.0
# 63               24.0
#
# [64 rows x 5 columns]

# %%
# Return 6 rows including row 15 itself.
# df.loc[] uses label indexing instead of integer based indexing with df.iloc[]
# Because of label indexing and not integer indexing, the count is different with row 15[10:15] included.

products.loc[10:15, ["Product Details", "Category", "Unit Price"]]
# Out:
#               Product Details      Category   Unit Price
# 10    HP ProBook 640 15.6inch   Workstation  PKR 189,000
# 11  HP EliteBook 840 16.0inch  workstation   PKR 214,000
# 12  HP EliteBook 650 17.3inch        Laptop  PKR 245,000
# 13    HP Pavilion 15 13.3inch       laptop   PKR 268,000
# 14    HP Pavilion 14 14.0inch        LAPTOP  PKR 298,000
# 15      HP Victus 16 15.6inch        Laptop  PKR 325,000

# %%
transactions23[transactions23["Discount %"] == "15%"]
# Out:
#          Order ID             Customer Code Product ID       Qty  \
# 21    ORD23-70022            BR2021/PK-1117    PRD-759  17 units
# 23    ORD23-70024              2019-PK_1085    PRD-871  22 units
# 40    ORD23-70041  Customer: PK-1083 (2017)    PRD-836  39 units
# 58    ORD23-70059            BR2016/PK-1012    PRD-619  25 units
# 68    ORD23-70069  Customer: PK-1183 (2017)    PRD-913  35 units
# ...           ...                       ...        ...       ...
# 1354  ORD23-71355              2019-PK_1215    PRD-514   8 units
# 1359  ORD23-71360              CUST-PK-1091    PRD-773  25 units
# 1360  ORD23-71361              2019-PK_1185    PRD-542  39 units
# 1376  ORD23-71377              cust_pk_1204    PRD-948  26 units
# 1387  ORD23-71388              2019-PK_1175    PRD-913  38 units
#
#          Sales Rep  Warehouse Discount % Order Month  \
# 21             NaN  WH/PEW/12        15%         Mar
# 23             NaN  WH HYD 08        15%         May
# 40             NaN  WH-HYD-12        15%         Oct
# 58             NaN  wh-lhr-03        15%         Apr
# 68    Hamza Sheikh  WH-LHR-09        15%         Feb
# ...            ...        ...        ...         ...
# 1354           NaN  wh-rwp-02        15%         Apr
# 1359           NaN  WH LHR 10        15%         Sep
# 1360           NaN  WH-KHI-04        15%         Oct
# 1376           NaN  WH-HYD-02        15%         Feb
# 1387           NaN  WH MUL 07        15%         Jan
#
#                                        Order Note  \
# 21                    send send updated quotation
# 23             very very late response from buyer
# 40           customer requested extended warranty
# 58    credit terms extended to 60 days [approved]
# 68           call the the customer before loading
# ...                                           ...
# 1354  credit terms extended to 60 days [approved]
# 1359                                    [PENDING]
# 1360                                     [CLOSED]
# 1376               resend the E-Mail with pricing
# 1387           documentation shared with accounts
#
#                                     Source URL
# 21    https://www.samsung-b2b.pk/orders/create
# 23         http://orders.lenovo-pk.com/renewal
# 40        https://www.acer-distributor.pk/cart
# 58          https://shop.hpstore.pk/enterprise
# 68         http://reseller.msi-pakistan.pk/new
# ...                                        ...
# 1354        https://shop.hpstore.pk/enterprise
# 1359       http://orders.lenovo-pk.com/b2b/new
# 1360      https://www.acer-distributor.pk/cart
# 1376       http://reseller.msi-pakistan.pk/new
# 1387  https://store.asus-pk.com/business/order
#
# [144 rows x 10 columns]

# %%
len(transactions23[transactions23["Discount %"] == "15%"])
# Out:
# 144

# %% [markdown]
# ---
# ## Part B - Cleaning Labels and Values
#
# *18 marks*
#
# Every column is text until you make it something else.

# %% [markdown]
# ### Question B1
# *6 marks - Medium*
#
# Every file has untidy column labels: trailing spaces, capitals, spaces between words, brackets, and a `%` sign.
#
# Write **one function** that cleans a single label - strip the ends, drop `(` and `)`, turn `%` into `pct`, turn spaces into underscores, lowercase everything - and apply it to the labels of **all six** DataFrames.

# %%
# Basic function to apply string functions
def cleaning_labels(labels):
    labels = labels.strip()
    labels = labels.replace("(","")
    labels = labels.replace(")","")
    labels = labels.replace("%","pct")
    labels = labels.replace(" ","_")
    labels = labels.lower()

    return labels

#converting and saving all dataframes into list called 'list_columns_labels'.
list_columns_labels = [customers,products, regions, returns,transactions23, transactions24]

#using for loop and applying to each label
for label in list_columns_labels:
    label.columns = [cleaning_labels(col) for col in label.columns]

# %%
transactions23
# Out:
#          order_id             customer_code product_id       qty  \
# 0     ORD23-70001              CUST-PK-1221    PRD-871  17 units
# 1     ORD23-70002              cust_pk_1239    PRD-864   3 units
# 2     ORD23-70003  Customer: PK-1178 (2022)    PRD-864  19 units
# 3     ORD23-70004              2019-PK_1035    PRD-885  12 units
# 4     ORD23-70005              CUST-PK-1216    PRD-794  14 units
# ...           ...                       ...        ...       ...
# 1395  ORD23-71396            BR2016/PK-1202    PRD-682   9 units
# 1396  ORD23-71397              2019-PK_1145    PRD-514  21 units
# 1397  ORD23-71398  Customer: PK-1178 (2022)    PRD-626  34 units
# 1398  ORD23-71399            BR2016/PK-1162    PRD-920   2 units
# 1399  ORD23-71400              cust_pk_1224    PRD-619  11 units
#
#           sales_rep  warehouse discount_pct order_month  \
# 0     Omar Siddiqui  WH-HYD-11           0%         Jun
# 1               NaN  WH/ISB/12          NaN         Jul
# 2               NaN  wh-skt-12         7.5%         Aug
# 3               NaN  WH SKT 08          10%         Sep
# 4               NaN  WH-FSD-03         7.5%         Oct
# ...             ...        ...          ...         ...
# 1395  Omar Siddiqui  WH RWP 10          NaN         Sep
# 1396            NaN  WH-HYD-06          NaN         Oct
# 1397            NaN  WH/SKT/08        12.5%         Nov
# 1398            NaN  wh-fsd-11           5%         Dec
# 1399   Sarah Nadeem  WH FSD 05          NaN         Jan
#
#                                    order_note  \
# 0                [RUSH] deliver before friday
# 1             [URGENT] client waiting at site
# 2             [HOLD] awaiting credit approval
# 3             [PRIORITY] escalated by manager
# 4      [BACKORDER] awaiting stock from vendor
# ...                                       ...
# 1395          [PRIORITY] escalated by manager
# 1396   [BACKORDER] awaiting stock from vendor
# 1397             [SPLIT] shipping in two lots
# 1398  confirm stock before dispatch [pending]
# 1399  packaging damaged on arrival [reported]
#
#                                           source_url
# 0        https://portal.techmazone.com.pk/orders/new
# 1                  http://b2b.dell-partners.pk/quote
# 2                   https://shop.hpstore.pk/checkout
# 3                http://orders.lenovo-pk.com/b2b/new
# 4               https://www.acer-distributor.pk/cart
# ...                                              ...
# 1395             http://orders.lenovo-pk.com/b2b/new
# 1396            https://www.acer-distributor.pk/cart
# 1397  https://portal.techmazone.com.pk/orders/repeat
# 1398             http://b2b.dell-partners.pk/renewal
# 1399        https://store.asus-pk.com/business/order
#
# [1400 rows x 10 columns]

# %% [markdown]
# ### Question B2
# *5 marks - Medium*
#
# In **both** transaction files convert the quantity column (`18 units`) to an **integer** and the discount column (`12.5%`, some blank) to a **float** where blank means **0**.
#
# The 2024 export does not use the same column labels as 2023. Do not rename anything yet.

# %%
# for quantity columns:
transactions23["qty"] = transactions23["qty"].str.strip('units').astype(int)
transactions24["quantity"] = transactions24["quantity"].str.strip('units').astype(int)

# %%
# for discount columns
transactions23["discount_pct"] = transactions23["discount_pct"].str.strip("%").astype(float)
transactions24["discount"] = transactions24["discount"].str.strip("%").astype(float)

# %%
print(transactions23.info(),transactions24.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       1400 non-null   object
#  1   customer_code  1400 non-null   object
#  2   product_id     1400 non-null   object
#  3   qty            1400 non-null   int64
#  4   sales_rep      188 non-null    object
#  5   warehouse      1400 non-null   object
#  6   discount_pct   1256 non-null   float64
#  7   order_month    1400 non-null   object
#  8   order_note     1400 non-null   object
#  9   source_url     1400 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 109.5+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1700 entries, 0 to 1699
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_no        1700 non-null   object
#  1   customer_id     1700 non-null   object
#  2   item_code       1700 non-null   object
#  3   quantity        1700 non-null   int64
#  4   representative  225 non-null    object
#  5   warehouse_code  1700 non-null   object
#  6   discount        1503 non-null   float64
#  7   month           1700 non-null   object
#  8   note            1700 non-null   object
#  9   source_link     1700 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 132.9+ KB
# None None

# %% [markdown]
# ### Question B3
# *7 marks - Hard*
#
# In `products`:
#
# 1. Turn `PKR 325,000` into the integer `325000`.
# 2. Fill missing warranty values with `12` and make the column an integer.
# 3. **Without regex**, create `brand` (the first word of `product_details`) and `screen_size_inches` (the trailing size, as a float).
# 4. `category` in `products` and `segment_type` in `customers` are both inconsistent - mixed capitals and stray spaces, and `segment_type` has blanks. Standardise both; blank segments should read `unknown`. Report the value counts and state how many genuinely distinct values exist in each.

# %%
products
# Out:
#    product_id                  product_details      category   unit_price  \
# 0     PRD-507      Dell Latitude 5420 15.6inch        Laptop  PKR 325,000
# 1     PRD-514      Dell Latitude 7430 16.0inch       laptop   PKR 364,000
# 2     PRD-521        Dell Vostro 3510 17.3inch        LAPTOP  PKR 410,000
# 3     PRD-528        Dell Vostro 5620 13.3inch        Laptop   PKR 72,000
# 4     PRD-535      Dell Inspiron 3511 14.0inch     Ultrabook   PKR 85,000
# ..        ...                              ...           ...          ...
# 59    PRD-920    Samsung Galaxy Book2 14.0inch  workstation   PKR 298,000
# 60    PRD-927    Samsung Galaxy Book3 15.6inch        Laptop  PKR 325,000
# 61    PRD-934  Samsung Notebook Flash 16.0inch       laptop   PKR 364,000
# 62    PRD-941      Samsung Odyssey 15 17.3inch        LAPTOP  PKR 410,000
# 63    PRD-948    Samsung Galaxy Book4 13.3inch        Laptop   PKR 72,000
#
#     warranty_months
# 0              36.0
# 1              12.0
# 2              24.0
# 3              12.0
# 4              12.0
# ..              ...
# 59             24.0
# 60             24.0
# 61             24.0
# 62             24.0
# 63             24.0
#
# [64 rows x 5 columns]

# %%
products["unit_price"] = (products["unit_price"].str.replace("PKR","").str.replace(",","").str.strip().astype(int))
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   product_id       64 non-null     object
#  1   product_details  64 non-null     object
#  2   category         64 non-null     object
#  3   unit_price       64 non-null     int64
#  4   warranty_months  58 non-null     float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 2.6+ KB

# %%
products["warranty_months"] = products["warranty_months"].fillna(12).astype(int)
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   product_id       64 non-null     object
#  1   product_details  64 non-null     object
#  2   category         64 non-null     object
#  3   unit_price       64 non-null     int64
#  4   warranty_months  64 non-null     int64
# dtypes: int64(2), object(3)
# memory usage: 2.6+ KB

# %%
products["product_details"].value_counts()
# Out:
# product_details
# Dell Latitude 5420 15.6inch      1
# Dell Latitude 7430 16.0inch      1
# Acer Predator 300 14.0inch       1
# Acer Chromebook 314 15.6inch     1
# Asus ExpertBook B1 16.0inch      1
#                                 ..
# Lenovo Yoga 7 16.0inch           1
# Acer Aspire 5 17.3inch           1
# Acer Aspire 7 13.3inch           1
# Acer Swift 3 14.0inch            1
# Samsung Galaxy Book4 13.3inch    1
# Name: count, Length: 64, dtype: int64

# %%
brand_split = products["product_details"].str.split(n=3,expand=True)
brand_split
# Out:
#           0         1      2         3
# 0      Dell  Latitude   5420  15.6inch
# 1      Dell  Latitude   7430  16.0inch
# 2      Dell    Vostro   3510  17.3inch
# 3      Dell    Vostro   5620  13.3inch
# 4      Dell  Inspiron   3511  14.0inch
# ..      ...       ...    ...       ...
# 59  Samsung    Galaxy  Book2  14.0inch
# 60  Samsung    Galaxy  Book3  15.6inch
# 61  Samsung  Notebook  Flash  16.0inch
# 62  Samsung   Odyssey     15  17.3inch
# 63  Samsung    Galaxy  Book4  13.3inch
#
# [64 rows x 4 columns]

# %%
# saving the brand split in particular columns:

products["brand"] = brand_split[0]
products["screen_size_inches"] = brand_split[3]
products
# Out:
#    product_id                  product_details      category  unit_price  \
# 0     PRD-507      Dell Latitude 5420 15.6inch        Laptop      325000
# 1     PRD-514      Dell Latitude 7430 16.0inch       laptop       364000
# 2     PRD-521        Dell Vostro 3510 17.3inch        LAPTOP      410000
# 3     PRD-528        Dell Vostro 5620 13.3inch        Laptop       72000
# 4     PRD-535      Dell Inspiron 3511 14.0inch     Ultrabook       85000
# ..        ...                              ...           ...         ...
# 59    PRD-920    Samsung Galaxy Book2 14.0inch  workstation       298000
# 60    PRD-927    Samsung Galaxy Book3 15.6inch        Laptop      325000
# 61    PRD-934  Samsung Notebook Flash 16.0inch       laptop       364000
# 62    PRD-941      Samsung Odyssey 15 17.3inch        LAPTOP      410000
# 63    PRD-948    Samsung Galaxy Book4 13.3inch        Laptop       72000
#
#     warranty_months    brand screen_size_inches
# 0                36     Dell           15.6inch
# 1                12     Dell           16.0inch
# 2                24     Dell           17.3inch
# 3                12     Dell           13.3inch
# 4                12     Dell           14.0inch
# ..              ...      ...                ...
# 59               24  Samsung           14.0inch
# 60               24  Samsung           15.6inch
# 61               24  Samsung           16.0inch
# 62               24  Samsung           17.3inch
# 63               24  Samsung           13.3inch
#
# [64 rows x 7 columns]

# %%
products["category"] = products["category"].str.strip().str.title()
products
# Out:
#    product_id                  product_details     category  unit_price  \
# 0     PRD-507      Dell Latitude 5420 15.6inch       Laptop      325000
# 1     PRD-514      Dell Latitude 7430 16.0inch       Laptop      364000
# 2     PRD-521        Dell Vostro 3510 17.3inch       Laptop      410000
# 3     PRD-528        Dell Vostro 5620 13.3inch       Laptop       72000
# 4     PRD-535      Dell Inspiron 3511 14.0inch    Ultrabook       85000
# ..        ...                              ...          ...         ...
# 59    PRD-920    Samsung Galaxy Book2 14.0inch  Workstation      298000
# 60    PRD-927    Samsung Galaxy Book3 15.6inch       Laptop      325000
# 61    PRD-934  Samsung Notebook Flash 16.0inch       Laptop      364000
# 62    PRD-941      Samsung Odyssey 15 17.3inch       Laptop      410000
# 63    PRD-948    Samsung Galaxy Book4 13.3inch       Laptop       72000
#
#     warranty_months    brand screen_size_inches
# 0                36     Dell           15.6inch
# 1                12     Dell           16.0inch
# 2                24     Dell           17.3inch
# 3                12     Dell           13.3inch
# 4                12     Dell           14.0inch
# ..              ...      ...                ...
# 59               24  Samsung           14.0inch
# 60               24  Samsung           15.6inch
# 61               24  Samsung           16.0inch
# 62               24  Samsung           17.3inch
# 63               24  Samsung           13.3inch
#
# [64 rows x 7 columns]

# %%
customers["segment_type"] = (customers["segment_type"].str.strip().str.title().fillna("Unknown").replace("","Unknown"))
customers
# Out:
#                 customer_code       customer_name segment_type   home_city  \
# 0                CUST-PK-1001  Yasir Distributors       Retail     Karachi
# 1              BR2016/PK-1002       Laiba Systems       Retail   Hyderabad
# 2    Customer: PK-1003 (2017)        Iqra Traders       Retail      Lahore
# 3                cust_pk_1004   Yusra Electronics       Retail  Faisalabad
# 4                2019-PK_1005       Fahad Traders    Corporate      Multan
# ..                        ...                 ...          ...         ...
# 257  Customer: PK-1258 (2022)   Imran Electronics    Corporate  Rawalpindi
# 258              cust_pk_1259         Saad & Sons    Corporate    Peshawar
# 259              2024-PK_1260    Jawad Associates    Corporate      Quetta
# 260              CUST-PK-1261       Fahad Systems   Government     Karachi
# 261            BR2016/PK-1262    Umair Associates   Government   Hyderabad
#
#      signup_year
# 0           2015
# 1           2016
# 2           2017
# 3           2018
# 4           2019
# ..           ...
# 257         2022
# 258         2023
# 259         2024
# 260         2015
# 261         2016
#
# [262 rows x 5 columns]

# %%
print("Product Category:")
print(products["category"].value_counts())
print(f"Distinct Categories: {products["category"].nunique()}")
# Out:
# Product Category:
# category
# Laptop         24
# Ultrabook      15
# Gaming         15
# Workstation    10
# Name: count, dtype: int64
# Distinct Categories: 4

# %%
print("segment_type:")
print(customers["segment_type"].value_counts())
print(f"Distinct Categories: {customers["segment_type"].nunique()}")
# Out:
# segment_type:
# segment_type
# Retail        60
# Corporate     57
# Government    54
# Education     42
# Reseller      42
# Unknown        7
# Name: count, dtype: int64
# Distinct Categories: 6

# %% [markdown]
# ---
# ## Part C - Filling the Gaps with Logic
#
# *13 marks*

# %% [markdown]
# ### Question C1
# *9 marks - Hard*
#
# The sales rep is written **once** at the top of a block of orders; the rows underneath are blank and belong to that same rep, until the next name appears.
#
# Fill in every blank in `transactions_2023`.
#
# Then report how many orders each rep handled, and confirm no blanks remain.

# %%
transactions23["sales_rep"].value_counts()
# Out:
# sales_rep
# Fatima Zafar     28
# Omar Siddiqui    27
# Sarah Nadeem     22
# Ali Raza         21
# Bilal Ansari     21
# Hamza Sheikh     21
# Hira Baig        18
# Ayesha Malik     18
# Salman Tariq     12
# Name: count, dtype: int64

# %%
transactions23["sales_rep"].isnull().sum()
# Out:
# np.int64(1212)

# %%
transactions23["sales_rep"] = transactions23["sales_rep"].ffill()

# %%
transactions23["sales_rep"].value_counts()
# Out:
# sales_rep
# Omar Siddiqui    208
# Fatima Zafar     195
# Ali Raza         183
# Bilal Ansari     161
# Sarah Nadeem     154
# Hamza Sheikh     141
# Ayesha Malik     138
# Hira Baig        128
# Salman Tariq      92
# Name: count, dtype: int64

# %%
transactions23["sales_rep"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Question C2
# *4 marks - Hard*
#
# Apply the same fill to `transactions_2024` - remember it labels the column differently.
#
# Then answer in a comment: if you had **stacked the two years first** and filled afterwards, what could go wrong? Be specific about the mechanism.

# %%
transactions24["representative"].value_counts()
# Out:
# representative
# Sarah Nadeem     32
# Nimra Qureshi    24
# Hira Baig        21
# Salman Tariq     21
# Bilal Ansari     20
# Fatima Zafar     20
# Ayesha Malik     19
# Adnan Hashmi     18
# Hamza Sheikh     17
# Omar Siddiqui    17
# Ali Raza         16
# Name: count, dtype: int64

# %%
transactions24["representative"] = transactions24["representative"].ffill()
transactions24
# Out:
#          order_no               customer_id item_code  quantity  \
# 0     ORD24-90001  Customer: PK-1048 (2022)   PRD-570         7
# 1     ORD24-90002            BR2016/PK-1022   PRD-871        26
# 2     ORD24-90003              CUST-PK-1071   PRD-836        23
# 3     ORD24-90004              2019-PK_1145   PRD-759        21
# 4     ORD24-90005              CUST-PK-1086   PRD-892        13
# ...           ...                       ...       ...       ...
# 1695  ORD24-91690            BR2016/PK-1072   PRD-528         7
# 1696  ORD24-91691  Customer: PK-1078 (2022)   PRD-738        40
# 1697  ORD24-91692              2019-PK_1005   PRD-626        12
# 1698  ORD24-91693              cust_pk_1004   PRD-668         7
# 1699  ORD24-91694              cust_pk_1184   PRD-668        40
#
#      representative warehouse_code  discount month  \
# 0      Adnan Hashmi      WH-SKT-02      15.0   Feb
# 1      Adnan Hashmi      WH/SKT/12       0.0   Mar
# 2      Adnan Hashmi      wh-qta-01      15.0   Apr
# 3      Adnan Hashmi      WH MUL 12       5.0   May
# 4      Adnan Hashmi      WH-FSD-07       NaN   Jun
# ...             ...            ...       ...   ...
# 1695   Hamza Sheikh      WH/PEW/07       5.0   Nov
# 1696   Hamza Sheikh      wh-qta-03      10.0   Dec
# 1697   Hamza Sheikh      WH LHR 12       5.0   Jan
# 1698   Hamza Sheikh      WH-ISB-03       7.5   Feb
# 1699   Hamza Sheikh      WH/ISB/01      20.0   Mar
#
#                                              note  \
# 0                    [RUSH] deliver before friday
# 1                 [URGENT] client waiting at site
# 2                 [HOLD] awaiting credit approval
# 3                 [PRIORITY] escalated by manager
# 4          [BACKORDER] awaiting stock from vendor
# ...                                           ...
# 1695   installation scheduled next week [planned]
# 1696  credit terms extended to 60 days [approved]
# 1697      serial numbers shared with buyer [done]
# 1698                                   [VERIFIED]
# 1699                                  [CANCELLED]
#
#                                       source_link
# 0     https://portal.techmazone.com.pk/orders/new
# 1               http://b2b.dell-partners.pk/quote
# 2                https://shop.hpstore.pk/checkout
# 3             http://orders.lenovo-pk.com/b2b/new
# 4            https://www.acer-distributor.pk/cart
# ...                                           ...
# 1695     https://www.samsung-b2b.pk/orders/create
# 1696           https://shop.hpstore.pk/enterprise
# 1697          http://orders.lenovo-pk.com/renewal
# 1698  https://portal.techmazone.com.pk/orders/new
# 1699            http://b2b.dell-partners.pk/quote
#
# [1700 rows x 10 columns]

# %%
transactions23["sales_rep"].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# - if you had stacked the transactions23 and transactions24 years first and filled afterwards, the 2nd year would be filled with first years last name
# - Example: `transaction_2023's sales_rep('Sarah Nadeem')` would become `transactions24's` first representative

# %% [markdown]
# ---
# ## Part D - Regular Expressions
#
# *36 marks*
#
# The largest section. The same information has been recorded five different ways by five different systems. Every question here has a wrong answer that runs without error - check your patterns against the data, not against your expectations.

# %% [markdown]
# ### Question D1
# *7 marks - Hard*
#
# The customer code has been entered five different ways across the files:
#
# ```
# CUST-PK-1001        BR2019/PK-1002        Customer: PK-1003 (2020)
# cust_pk_1004        2022-PK_1005
# ```
#
# Some of these layouts also contain a **four-digit year**. A pattern of `(\d{4})` will therefore extract the wrong number from part of the file.
#
# 1. Write **one** regular expression that extracts the correct customer number from **all five** layouts into an integer column `cust_id`. Apply it to `transactions_2023`, `transactions_2024` and `customers`.
# 2. Prove your pattern was necessary: report **how many rows a naive `(\d{4})` would have got wrong**.

# %%
pattern = r"[Pp][Kk][-_ ](\d{4})"
customers["cust_id"] = customers["customer_code"].str.extract(pattern).astype(int)
customers["customer_code"]
# Out:
# 0                  CUST-PK-1001
# 1                BR2016/PK-1002
# 2      Customer: PK-1003 (2017)
# 3                  cust_pk_1004
# 4                  2019-PK_1005
#                  ...
# 257    Customer: PK-1258 (2022)
# 258                cust_pk_1259
# 259                2024-PK_1260
# 260                CUST-PK-1261
# 261              BR2016/PK-1262
# Name: customer_code, Length: 262, dtype: object

# %%
customers["customer_code"]
# Out:
# 0                  CUST-PK-1001
# 1                BR2016/PK-1002
# 2      Customer: PK-1003 (2017)
# 3                  cust_pk_1004
# 4                  2019-PK_1005
#                  ...
# 257    Customer: PK-1258 (2022)
# 258                cust_pk_1259
# 259                2024-PK_1260
# 260                CUST-PK-1261
# 261              BR2016/PK-1262
# Name: customer_code, Length: 262, dtype: object

# %%
pattern = r"[Pp][Kk][-_ ](\d{4})"
transactions23["cust_id"] = transactions23["customer_code"].str.extract(pattern).astype(int)
transactions23
# Out:
#          order_id             customer_code product_id  qty      sales_rep  \
# 0     ORD23-70001              CUST-PK-1221    PRD-871   17  Omar Siddiqui
# 1     ORD23-70002              cust_pk_1239    PRD-864    3  Omar Siddiqui
# 2     ORD23-70003  Customer: PK-1178 (2022)    PRD-864   19  Omar Siddiqui
# 3     ORD23-70004              2019-PK_1035    PRD-885   12  Omar Siddiqui
# 4     ORD23-70005              CUST-PK-1216    PRD-794   14  Omar Siddiqui
# ...           ...                       ...        ...  ...            ...
# 1395  ORD23-71396            BR2016/PK-1202    PRD-682    9  Omar Siddiqui
# 1396  ORD23-71397              2019-PK_1145    PRD-514   21  Omar Siddiqui
# 1397  ORD23-71398  Customer: PK-1178 (2022)    PRD-626   34  Omar Siddiqui
# 1398  ORD23-71399            BR2016/PK-1162    PRD-920    2  Omar Siddiqui
# 1399  ORD23-71400              cust_pk_1224    PRD-619   11   Sarah Nadeem
#
#       warehouse  discount_pct order_month  \
# 0     WH-HYD-11           0.0         Jun
# 1     WH/ISB/12           NaN         Jul
# 2     wh-skt-12           7.5         Aug
# 3     WH SKT 08          10.0         Sep
# 4     WH-FSD-03           7.5         Oct
# ...         ...           ...         ...
# 1395  WH RWP 10           NaN         Sep
# 1396  WH-HYD-06           NaN         Oct
# 1397  WH/SKT/08          12.5         Nov
# 1398  wh-fsd-11           5.0         Dec
# 1399  WH FSD 05           NaN         Jan
#
#                                    order_note  \
# 0                [RUSH] deliver before friday
# 1             [URGENT] client waiting at site
# 2             [HOLD] awaiting credit approval
# 3             [PRIORITY] escalated by manager
# 4      [BACKORDER] awaiting stock from vendor
# ...                                       ...
# 1395          [PRIORITY] escalated by manager
# 1396   [BACKORDER] awaiting stock from vendor
# 1397             [SPLIT] shipping in two lots
# 1398  confirm stock before dispatch [pending]
# 1399  packaging damaged on arrival [reported]
#
#                                           source_url  cust_id
# 0        https://portal.techmazone.com.pk/orders/new     1221
# 1                  http://b2b.dell-partners.pk/quote     1239
# 2                   https://shop.hpstore.pk/checkout     1178
# 3                http://orders.lenovo-pk.com/b2b/new     1035
# 4               https://www.acer-distributor.pk/cart     1216
# ...                                              ...      ...
# 1395             http://orders.lenovo-pk.com/b2b/new     1202
# 1396            https://www.acer-distributor.pk/cart     1145
# 1397  https://portal.techmazone.com.pk/orders/repeat     1178
# 1398             http://b2b.dell-partners.pk/renewal     1162
# 1399        https://store.asus-pk.com/business/order     1224
#
# [1400 rows x 11 columns]

# %%
pattern = r"[Pp][Kk][-_ ](\d{4})"
transactions24["cust_id"] = transactions24["customer_id"].str.extract(pattern).astype(int)
transactions24
# Out:
#          order_no               customer_id item_code  quantity  \
# 0     ORD24-90001  Customer: PK-1048 (2022)   PRD-570         7
# 1     ORD24-90002            BR2016/PK-1022   PRD-871        26
# 2     ORD24-90003              CUST-PK-1071   PRD-836        23
# 3     ORD24-90004              2019-PK_1145   PRD-759        21
# 4     ORD24-90005              CUST-PK-1086   PRD-892        13
# ...           ...                       ...       ...       ...
# 1695  ORD24-91690            BR2016/PK-1072   PRD-528         7
# 1696  ORD24-91691  Customer: PK-1078 (2022)   PRD-738        40
# 1697  ORD24-91692              2019-PK_1005   PRD-626        12
# 1698  ORD24-91693              cust_pk_1004   PRD-668         7
# 1699  ORD24-91694              cust_pk_1184   PRD-668        40
#
#      representative warehouse_code  discount month  \
# 0      Adnan Hashmi      WH-SKT-02      15.0   Feb
# 1      Adnan Hashmi      WH/SKT/12       0.0   Mar
# 2      Adnan Hashmi      wh-qta-01      15.0   Apr
# 3      Adnan Hashmi      WH MUL 12       5.0   May
# 4      Adnan Hashmi      WH-FSD-07       NaN   Jun
# ...             ...            ...       ...   ...
# 1695   Hamza Sheikh      WH/PEW/07       5.0   Nov
# 1696   Hamza Sheikh      wh-qta-03      10.0   Dec
# 1697   Hamza Sheikh      WH LHR 12       5.0   Jan
# 1698   Hamza Sheikh      WH-ISB-03       7.5   Feb
# 1699   Hamza Sheikh      WH/ISB/01      20.0   Mar
#
#                                              note  \
# 0                    [RUSH] deliver before friday
# 1                 [URGENT] client waiting at site
# 2                 [HOLD] awaiting credit approval
# 3                 [PRIORITY] escalated by manager
# 4          [BACKORDER] awaiting stock from vendor
# ...                                           ...
# 1695   installation scheduled next week [planned]
# 1696  credit terms extended to 60 days [approved]
# 1697      serial numbers shared with buyer [done]
# 1698                                   [VERIFIED]
# 1699                                  [CANCELLED]
#
#                                       source_link  cust_id
# 0     https://portal.techmazone.com.pk/orders/new     1048
# 1               http://b2b.dell-partners.pk/quote     1022
# 2                https://shop.hpstore.pk/checkout     1071
# 3             http://orders.lenovo-pk.com/b2b/new     1145
# 4            https://www.acer-distributor.pk/cart     1086
# ...                                           ...      ...
# 1695     https://www.samsung-b2b.pk/orders/create     1072
# 1696           https://shop.hpstore.pk/enterprise     1078
# 1697          http://orders.lenovo-pk.com/renewal     1005
# 1698  https://portal.techmazone.com.pk/orders/new     1004
# 1699            http://b2b.dell-partners.pk/quote     1184
#
# [1700 rows x 11 columns]

# %%
# Naive pattern:
naive_pattern = customers["customer_code"].str.extract(r"(\d{4})").astype(int)
naive_pattern
# Out:
#         0
# 0    1001
# 1    2016
# 2    1003
# 3    1004
# 4    2019
# ..    ...
# 257  1258
# 258  1259
# 259  2024
# 260  1261
# 261  2016
#
# [262 rows x 1 columns]

# %%
naive_pattern = customers["customer_code"].str.extract(r"(\d{4})").astype(int)
not_naive_pattern = customers["customer_code"].str.extract(r"[Pp][Kk][-_](\d{4})").astype(int)
# print(not_naive_pattern)
# print(naive_pattern)

difference = (naive_pattern[0] != not_naive_pattern[0])

print("Difference Between Naive and Non-Naive Pattern")
print(pd.concat([naive_pattern[difference],
                 not_naive_pattern[difference]], axis=1))
# Out:
# Difference Between Naive and Non-Naive Pattern
#         0     0
# 1    2016  1002
# 4    2019  1005
# 6    2021  1007
# 9    2024  1010
# 11   2016  1012
# ..    ...   ...
# 251  2016  1252
# 254  2019  1255
# 256  2021  1257
# 259  2024  1260
# 261  2016  1262
#
# [105 rows x 2 columns]

# %% [markdown]
# ### Question D2
# *5 marks - Hard*
#
# Warehouse codes have been entered four ways:
#
# ```
# WH-LHR-09        WH/ISB/04        wh-isb-05        WH ISB 08
# ```
#
# 1. Write **one** regular expression that pulls out the three-letter region code from all four, and store it as **uppercase** in a column `region_code` on both transaction files.
# 2. Report how many rows a stricter pattern of `WH-([A-Z]{3})-` would have **silently failed** to match.

# %%
pattern = r"WH[-/ ]([\w+]{3})[-/ ]"
transactions23["region_code"] = (transactions23["warehouse"].str.extract(pattern, expand=False).str.upper())
transactions23
# Out:
#          order_id             customer_code product_id  qty      sales_rep  \
# 0     ORD23-70001              CUST-PK-1221    PRD-871   17  Omar Siddiqui
# 1     ORD23-70002              cust_pk_1239    PRD-864    3  Omar Siddiqui
# 2     ORD23-70003  Customer: PK-1178 (2022)    PRD-864   19  Omar Siddiqui
# 3     ORD23-70004              2019-PK_1035    PRD-885   12  Omar Siddiqui
# 4     ORD23-70005              CUST-PK-1216    PRD-794   14  Omar Siddiqui
# ...           ...                       ...        ...  ...            ...
# 1395  ORD23-71396            BR2016/PK-1202    PRD-682    9  Omar Siddiqui
# 1396  ORD23-71397              2019-PK_1145    PRD-514   21  Omar Siddiqui
# 1397  ORD23-71398  Customer: PK-1178 (2022)    PRD-626   34  Omar Siddiqui
# 1398  ORD23-71399            BR2016/PK-1162    PRD-920    2  Omar Siddiqui
# 1399  ORD23-71400              cust_pk_1224    PRD-619   11   Sarah Nadeem
#
#       warehouse  discount_pct order_month  \
# 0     WH-HYD-11           0.0         Jun
# 1     WH/ISB/12           NaN         Jul
# 2     wh-skt-12           7.5         Aug
# 3     WH SKT 08          10.0         Sep
# 4     WH-FSD-03           7.5         Oct
# ...         ...           ...         ...
# 1395  WH RWP 10           NaN         Sep
# 1396  WH-HYD-06           NaN         Oct
# 1397  WH/SKT/08          12.5         Nov
# 1398  wh-fsd-11           5.0         Dec
# 1399  WH FSD 05           NaN         Jan
#
#                                    order_note  \
# 0                [RUSH] deliver before friday
# 1             [URGENT] client waiting at site
# 2             [HOLD] awaiting credit approval
# 3             [PRIORITY] escalated by manager
# 4      [BACKORDER] awaiting stock from vendor
# ...                                       ...
# 1395          [PRIORITY] escalated by manager
# 1396   [BACKORDER] awaiting stock from vendor
# 1397             [SPLIT] shipping in two lots
# 1398  confirm stock before dispatch [pending]
# 1399  packaging damaged on arrival [reported]
#
#                                           source_url  cust_id region_code
# 0        https://portal.techmazone.com.pk/orders/new     1221         HYD
# 1                  http://b2b.dell-partners.pk/quote     1239         ISB
# 2                   https://shop.hpstore.pk/checkout     1178         NaN
# 3                http://orders.lenovo-pk.com/b2b/new     1035         SKT
# 4               https://www.acer-distributor.pk/cart     1216         FSD
# ...                                              ...      ...         ...
# 1395             http://orders.lenovo-pk.com/b2b/new     1202         RWP
# 1396            https://www.acer-distributor.pk/cart     1145         HYD
# 1397  https://portal.techmazone.com.pk/orders/repeat     1178         SKT
# 1398             http://b2b.dell-partners.pk/renewal     1162         NaN
# 1399        https://store.asus-pk.com/business/order     1224         FSD
#
# [1400 rows x 12 columns]

# %%
pattern = r"WH[-/ ]([\w+]{3})[-/ ]"
transactions24["region_code"] = (transactions24["warehouse_code"].str.extract(pattern, expand=False).str.upper())
transactions24
# Out:
#          order_no               customer_id item_code  quantity  \
# 0     ORD24-90001  Customer: PK-1048 (2022)   PRD-570         7
# 1     ORD24-90002            BR2016/PK-1022   PRD-871        26
# 2     ORD24-90003              CUST-PK-1071   PRD-836        23
# 3     ORD24-90004              2019-PK_1145   PRD-759        21
# 4     ORD24-90005              CUST-PK-1086   PRD-892        13
# ...           ...                       ...       ...       ...
# 1695  ORD24-91690            BR2016/PK-1072   PRD-528         7
# 1696  ORD24-91691  Customer: PK-1078 (2022)   PRD-738        40
# 1697  ORD24-91692              2019-PK_1005   PRD-626        12
# 1698  ORD24-91693              cust_pk_1004   PRD-668         7
# 1699  ORD24-91694              cust_pk_1184   PRD-668        40
#
#      representative warehouse_code  discount month  \
# 0      Adnan Hashmi      WH-SKT-02      15.0   Feb
# 1      Adnan Hashmi      WH/SKT/12       0.0   Mar
# 2      Adnan Hashmi      wh-qta-01      15.0   Apr
# 3      Adnan Hashmi      WH MUL 12       5.0   May
# 4      Adnan Hashmi      WH-FSD-07       NaN   Jun
# ...             ...            ...       ...   ...
# 1695   Hamza Sheikh      WH/PEW/07       5.0   Nov
# 1696   Hamza Sheikh      wh-qta-03      10.0   Dec
# 1697   Hamza Sheikh      WH LHR 12       5.0   Jan
# 1698   Hamza Sheikh      WH-ISB-03       7.5   Feb
# 1699   Hamza Sheikh      WH/ISB/01      20.0   Mar
#
#                                              note  \
# 0                    [RUSH] deliver before friday
# 1                 [URGENT] client waiting at site
# 2                 [HOLD] awaiting credit approval
# 3                 [PRIORITY] escalated by manager
# 4          [BACKORDER] awaiting stock from vendor
# ...                                           ...
# 1695   installation scheduled next week [planned]
# 1696  credit terms extended to 60 days [approved]
# 1697      serial numbers shared with buyer [done]
# 1698                                   [VERIFIED]
# 1699                                  [CANCELLED]
#
#                                       source_link  cust_id region_code
# 0     https://portal.techmazone.com.pk/orders/new     1048         SKT
# 1               http://b2b.dell-partners.pk/quote     1022         SKT
# 2                https://shop.hpstore.pk/checkout     1071         NaN
# 3             http://orders.lenovo-pk.com/b2b/new     1145         MUL
# 4            https://www.acer-distributor.pk/cart     1086         FSD
# ...                                           ...      ...         ...
# 1695     https://www.samsung-b2b.pk/orders/create     1072         PEW
# 1696           https://shop.hpstore.pk/enterprise     1078         NaN
# 1697          http://orders.lenovo-pk.com/renewal     1005         LHR
# 1698  https://portal.techmazone.com.pk/orders/new     1004         ISB
# 1699            http://b2b.dell-partners.pk/quote     1184         ISB
#
# [1700 rows x 12 columns]

# %%
# There are many rows, strict pat
strict_pattern = transactions24["warehouse_code"].str.extract(r"WH-([A-Z]{3})-", expand=False).str.upper()
not_pattern = transactions24["warehouse_code"].str.extract(r"WH[-/ ]([\w+]{3})[-/ ]", expand=False).str.upper()

difference = strict_pattern != not_pattern
difference.value_counts()

# print("Difference Between Strict and Not Strict Pattern")
# print(pd.concat([strict_pattern[difference],
#                  not_pattern[difference]], axis=1))
# Out:
# warehouse_code
# True     1274
# False     426
# Name: count, dtype: int64

# %% [markdown]
# ### Question D3
# *6 marks - Hard*
#
# The `order_note` column contains bracketed status tags such as `[RUSH]`, `[pending]`, `[pdf]`.
#
# Using **anchors**, report three separate counts for `transactions_2023`:
#
# 1. notes that **begin** with a tag
# 2. notes that **end** with a tag
# 3. notes that are **nothing but** a tag
#
# Then show two example notes from each of the three groups.

# %% [markdown]
# ### Question D4
# *6 marks - Hard*
#
# Some notes contain an accidental **repeated word**, either immediately (`urgent urgent needs dispatch`) or with one word between them (`quote sent quote by courier`).
#
# Using **backreferences**:
#
# 1. Count and list the notes where a word repeats **immediately**.
# 2. Count and list the notes where a word repeats with **exactly one word in between**.
# 3. In a comment, explain why the pattern for part 2 must not simply be the part 1 pattern with an extra `\s\w+`.

# %% [markdown]
# ### Question D5
# *6 marks - Hard*
#
# Two questions on `product_details`, using **lookarounds** and **word boundaries**:
#
# 1. List every product whose name contains `Book` **not preceded by** `Mac`. (`ProBook`, `ZenBook` count; `MacBook` must not.)
# 2. List every product containing `pro` as a **standalone word**, case-insensitive. (`MacBook Pro` counts; `ProBook` must not.)
# 3. In a comment, explain why part 2 cannot be solved with `str.contains("Pro")`.

# %% [markdown]
# ### Question D6
# *6 marks - Hard*
#
# Two final regex tasks on `transactions_2023`:
#
# 1. From `source_url`, use **named capturing groups** to split each URL into `protocol`, `domain` and `path` in a single extraction. Report how many orders came from each domain and how many used `https`.
# 2. The notes spell the same word four ways: `e-mail`, `e mail`, `email`, `E-Mail`. Show the four spellings and their counts, then rewrite the column so all four become `email`. Prove it worked.

# %% [markdown]
# ---
# ## Part E - Combining the Tables
#
# *14 marks*
#
# Six files, one analysis table. Nothing in this section raises an exception. It just gives you the wrong answer.

# %% [markdown]
# ### Question E1
# *6 marks - Hard*
#
# 1. Rename the 2024 columns to match 2023, add a `year` column to each file, and stack them into one DataFrame `tx` with a clean `0..n` index.
# 2. Some order IDs were entered twice. Find every repeated ID and show the offending rows.
#
# **You may not use `duplicated()`, `drop_duplicates()` or `isin()`.**

# %% [markdown]
# ### Question E2
# *8 marks - Hard*
#
# 1. Join `tx` to `products`, `customers` and `regions` into one table `m`. State in a comment which join type you used and why, and prove no rows were gained or lost.
# 2. Which **registered customers have never placed an order**?
# 3. Which **catalogue products were never sold**?
#
# **You may not use `isin()`, `isnull()` or `notnull()`.** Build the membership test yourself.

# %% [markdown]
# ---
# ## Part F - Aggregation and Analysis
#
# *11 marks*
#
# Answer the questions the business actually asked.

# %% [markdown]
# ### Question F1
# *5 marks - Medium*
#
# 1. Add `gross_revenue` (quantity x unit price) and `net_revenue` (after discount) to `m`. Report the total net revenue and the total discount given away.
# 2. Using `groupby`, report the number of orders and the total net revenue per **sales rep**.
# 3. Use `get_group` to show the first three transactions of any one rep.

# %% [markdown]
# ### Question F2
# *6 marks - Hard*
#
# 1. Build a pivot table with **region name** down the side, **category** across the top, and **total** net revenue in the cells.
# 2. For each region, find the single **brand** that earned the most net revenue, and how much.
#
# For part 2 you must use a **loop over the groups** and track the maximum yourself - do not use `idxmax`, `max`, `nlargest` or `sort_values`.
