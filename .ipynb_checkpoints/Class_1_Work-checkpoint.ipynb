# %% [markdown]
# # CLASS 1 WORK
#
# ## DATA TYPES IN PYTHON
# - integer (1,2,3,4,5)
# - float (5.2,10.1,88.6)
# - string ("Name")

# %%
print(77)
# Out:
# 77

# %%
print(92.3)
# Out:
# 92.3

# %%
print("name")
# Out:
# name

# %% [markdown]
# ### ARITHMETIC OPERATOR
# - =
# - /
# - //
# - %

# %%
i = 10
print(i)
# Out:
# 10

# %%
name = "KHAN"
print(name)
# Out:
# KHAN

# %%
divide = 10/2
print(divide)
# Out:
# 5.0

# %%
floor_division = 35//4
print(floor_division)
# Out:
# 8

# %%
modulos = 90%8
print(modulos)
# Out:
# 2
