# %% [markdown]
# # LECTURE 1 NOTEBOOK

# %% [markdown]
# ## Data Types in Python:
# 1. Interger,
# 2. Float,
# 3. String
#
# ## Functions in Python:
# 1. print(),
# 2. type()

# %%
print(1828)
# Out:
# 1828

# %%
print(18.28)
# Out:
# 18.28

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(type(1828))
# Out:
# <class 'int'>

# %%
print(type("Hello World"))
# Out:
# <class 'str'>

# %%
print(type(18.28))
# Out:
# <class 'float'>

# %% [markdown]
# # Arithmetic Operators in Python:
# +, -, *, /, //, **, %

# %%
print(7 + 3)
# Out:
# 10

# %%
print(7-3)
# Out:
# 4

# %%
print(3.5 + 3.5)
# Out:
# 7.0

# %%
print("18" + 10)

# %% [markdown]
# The error in above code cell is due to 18 is string data type and 10 is integer and mathematical calculation cannot be done

# %%
floor_division = 35//4
print(floor_division)
# Out:
# 8

# %%
modulos = 90%8
print(modulos)
# Out:
# 2

# %% [markdown]
# ## PEMDAS in Python:
# - P = PARENTHESIS ()
# - E = EXPONENT **
# - M = MULTIPLICATION *
# - D = DIVISON /, //, %
# - A = ADDITION +
# - S = SUBTRACTION -

# %%
pemdas = (18 ** 10+(10+8) * 28-10)
print(pemdas)
# Out:
# 3570467227118

# %%
print(10%2 + 3**2)
# Out:
# 9

# %%
print(10//2 + 3**2)
# Out:
# 14
