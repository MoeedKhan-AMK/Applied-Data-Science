# %% [markdown]
# ## REGULAR EXPRESSION LEARNING
# - 1. re.search()          → find a pattern in text
# - 2. span                 → index position of match
# - 3. []                   → character class — any one character from the set
# - 4. [msb]                → match m or s or b
# - 5. [A-Z], [a-z], [0-9]  → ranges inside character class
# - 6. [Pp]ython            → case insensitive matching
# - 7. \d                   → shortcut for [0-9]
# - 8. \w                   → shortcut for [A-Za-z0-9_]
# - 9. {3}                  → exactly 3 times
# - 10. {3,5}               → 3 to 5 times
# - 11. {,3}                → 0 to 3 times
# - 12. {8,}                → 8 or more times
# - 13. *                   → 0 or more (a{0,})
# - 14. +                   → 1 or more (a{1,})
# - 15. ?                   → 0 or 1  (a{0,1})
# - 16. ()                  → capture group — used with .extract()
# - 17. .                   → any character except newline
# - 18. str.contains()      → filter rows matching pattern
# - 19. str.extract()       → pull out matched text
# - 20. value_counts()      → count extracted results

# %%
import pandas as pd
import re

# %%
hn = pd.read_csv("../Pandas/hacker_news.csv")
hn.head(5)
# Out:
#          id                                              title  \
# 0  12579008  You have two days to comment if you want stem ...
# 1  12579005                         SQLAR  the SQLite Archiver
# 2  12578997  What if we just printed a flatscreen televisio...
# 3  12578989                                  algorithmic music
# 4  12578979  How the Data Vault Enables the Next-Gen Data W...
#
#                                                  url  num_points  \
# 0  http://www.regulations.gov/document?D=FDA-2015...           1
# 1   https://www.sqlite.org/sqlar/doc/trunk/README.md           1
# 2  https://medium.com/vanmoof/our-secrets-out-f21...           1
# 3  http://cacm.acm.org/magazines/2011/7/109891-al...           1
# 4  https://www.talend.com/blog/2016/05/12/talend-...           1
#
#    num_comments        author      created_at
# 0             0       altstar  9/26/2016 3:26
# 1             0      blacksqr  9/26/2016 3:24
# 2             0  pavel_lishin  9/26/2016 3:19
# 3             0  poindontcare  9/26/2016 3:16
# 4             0   markgainor1  9/26/2016 3:14

# %%
# We are searching for and in given text
re.search("and", "I have two hands")
# Out:
# <re.Match object; span=(12, 15), match='and'>

# %%
# span=(12,15): This is index number where and was found
"I have two hands"[12:15]
# Out:
# 'and'

# %%
title = hn["title"]

# %%
"mend","send","bend"
re.search("[msb]end", "My name is ssend")
# Out:
# <re.Match object; span=(12, 16), match='send'>

# %%
pattern = "[Pp]ython"

title[title.str.contains(pattern)]
# Out:
# 109           Solve a wooden puzzle with Python and Jupyter
# 257       A fast PostgreSQL client library for Python: 3...
# 284                                     Asynchronous Python
# 444       Python 4 Kids: Python for Kids: Python 3  Proj...
# 478       Cubr  A Rubiks Cube Solver Written in Python a...
#                                 ...
# 292474    OAuth 2.0 for Google (Analytics) API with Pyth...
# 292506      Mac OS X Keychain Forensic Tool (Python, GPLv2)
# 292735    Show HN: Combo, the Simple Python Package Manager
# 292821             Try to not use the Python C API directly
# 293085      Hackerone disclosed report aggregator in python
# Name: title, Length: 2572, dtype: object

# %%
pattern = "[Rr]uby"

title[title.str.contains(pattern)]
# Out:
# 1291                        Wrote a simple ps clone in ruby
# 1497       Ruby Poltergeist gem the best way to scrape data
# 1624      A proposal of new concurrency model for Ruby 3...
# 1734      Ruby gem to fetch gocd information as rich mod...
# 1981                    Ruby vs. Python, the Definitive FAQ
#                                 ...
# 291994    Statically typed Ruby  method signatures somet...
# 292008                       Pros and Cons of Ruby on Rails
# 292456                       PostgreSQL for Ruby Developers
# 292501            Ruby Robotic Vacuum Programming Challenge
# 292779          Collection of expectation matchers for Ruby
# Name: title, Length: 920, dtype: object

# %%
# 1000-2999

pattern = "[12][0123456789][0123456789][0123456789]"
#2090

title[title.str.contains(pattern)]
# Out:
# 20              OMeta#: Who? What? When? Where? Why? (2008)
# 24                  Segas Plans for World Domination (1993)
# 48        My CppCon 2016 trip report (thoughts on my fav...
# 59                       Mistakenly Seeking Solitude (2014)
# 66        Anti-Spoofing, BCP 38, and the Tragedy of the ...
#                                 ...
# 293076    The Effects of Computer Programming on the Bra...
# 293086    GM crops created superweed, say scientists (2005)
# 293104    Google's new logo was created by Russian desig...
# 293115    Attention and awareness in stage magic: turnin...
# 293116                    Dying vets fuck you letter (2013)
# Name: title, Length: 15487, dtype: object

# %%
# 1000-2999

pattern = "[1-2][0-9][0-9][0-9]"
#2090

title[title.str.contains(pattern)]
# Out:
# 20              OMeta#: Who? What? When? Where? Why? (2008)
# 24                  Segas Plans for World Domination (1993)
# 48        My CppCon 2016 trip report (thoughts on my fav...
# 59                       Mistakenly Seeking Solitude (2014)
# 66        Anti-Spoofing, BCP 38, and the Tragedy of the ...
#                                 ...
# 293076    The Effects of Computer Programming on the Bra...
# 293086    GM crops created superweed, say scientists (2005)
# 293104    Google's new logo was created by Russian desig...
# 293115    Attention and awareness in stage magic: turnin...
# 293116                    Dying vets fuck you letter (2013)
# Name: title, Length: 15487, dtype: object

# %% [markdown]
# ## Numeric Quantifier
#     * a{3} -> the character `a` three times
#     * a{3,5} -> the character `a` three, four or five times
#     * a{,3} -> the character `a` zero, one, two or three times
#     * a{8,} -> the character `a` eight or more times

# %%
"mend", "send", "bend"

# sd,sad,saad,saaad
re.search("sa{,3}d", "My name is saad")
# Out:
# <re.Match object; span=(11, 15), match='saad'>

# %% [markdown]
# ## Single Character Quantifier
#
#     * a* -> equivalent to a{0,} zero or more
#     * a+ -> equivalent to a{1,} one or more
#     * a? -> equivalent to a{0,1} zero or one

# %%
# 1000-2999
# here [0-9]{3} means that bracket multiply by 3

pattern = "[12][0-9]{3}"

title[title.str.contains(pattern)]
# Out:
# 20              OMeta#: Who? What? When? Where? Why? (2008)
# 24                  Segas Plans for World Domination (1993)
# 48        My CppCon 2016 trip report (thoughts on my fav...
# 59                       Mistakenly Seeking Solitude (2014)
# 66        Anti-Spoofing, BCP 38, and the Tragedy of the ...
#                                 ...
# 293076    The Effects of Computer Programming on the Bra...
# 293086    GM crops created superweed, say scientists (2005)
# 293104    Google's new logo was created by Russian desig...
# 293115    Attention and awareness in stage magic: turnin...
# 293116                    Dying vets fuck you letter (2013)
# Name: title, Length: 15487, dtype: object

# %%
# 1000-2999
# \d = [0-9]

pattern = "[12]\d{3}"

title[title.str.contains(pattern)]
# Out:
# 20              OMeta#: Who? What? When? Where? Why? (2008)
# 24                  Segas Plans for World Domination (1993)
# 48        My CppCon 2016 trip report (thoughts on my fav...
# 59                       Mistakenly Seeking Solitude (2014)
# 66        Anti-Spoofing, BCP 38, and the Tragedy of the ...
#                                 ...
# 293076    The Effects of Computer Programming on the Bra...
# 293086    GM crops created superweed, say scientists (2005)
# 293104    Google's new logo was created by Russian desig...
# 293115    Attention and awareness in stage magic: turnin...
# 293116                    Dying vets fuck you letter (2013)
# Name: title, Length: 15487, dtype: object

# %%
# email, e-mail

pattern = "e-{0,1}mail"

title[title.str.contains(pattern)]
# Out:
# 90        This is what happens when you reply to spam email
# 173                  Correct way to validate email adresses
# 1010      Obama used a pseudonym in emails with Clinton,...
# 1012      The most broken part of your user experience i...
# 1029                 Visualization of Clinton email scandal
#                                 ...
# 291942    U.S., tech industry fight over email privacy h...
# 292071    U.S., tech industry fight over email privacy h...
# 292094    Why you shouldn't use disposable email address...
# 292341    Ex-Tesla engineer could face prison for email ...
# 292778    Show HN: LeadStage emaildomaindb  Flag email a...
# Name: title, Length: 873, dtype: object

# %%
# email, e-mail

pattern = "(e-?mail)" #() is capture group, in extract, capture group is necessary

title.str.extract(pattern).value_counts(dropna= False)
# Out:
# 0
# NaN       292246
# email        821
# e-mail        52
# Name: count, dtype: int64

# %%
# [pdf], [video], [..]
# \w = [A-Za-z0-9_]

pattern = "\[\w+\]"
title[title.str.contains(pattern)]
# Out:
# 36        Cuba's DIY Inventions from 30 Years of Isolati...
# 114       A Possible Future of Software Development by  ...
# 153                                  FreeBSD Issue #1 [pdf]
# 154          Proprietary versus open instruction sets [pdf]
# 217                         Forever Alone Programming [FAP]
#                                 ...
# 292904                      How to Write About Africa [pdf]
# 292944    Interactively Develop a Reactjs Application [v...
# 293044    The Synthesis of Reliable Organisms from Unrel...
# 293075    Saul Bass Pitch Video for Bell System Logo Red...
# 293115    Attention and awareness in stage magic: turnin...
# Name: title, Length: 5871, dtype: object

# %%
# [pdf], [video], [..]
# . = any character or special character except newline

pattern = "(\[.+\])"
title.str.extract(pattern).value_counts()
# Out:
# 0
# [pdf]                           3520
# [video]                         1521
# [audio]                           65
# [2015]                            21
# [Infographic]                     17
#                                 ...
# [List]                             1
# [Little Free Libraries]            1
# [Live Demo and Ready Sample]       1
# [Live Demo and Sample]             1
# [yourtube]                         1
# Name: count, Length: 994, dtype: int64

# %%
# [pdf], [video], [..]
# \w = [A-Za-z0-9_]

pattern = "(\[\w+\])"
title.str.extract(pattern).value_counts()
# Out:
# 0
# [pdf]            3531
# [video]          1524
# [audio]            65
# [2015]             23
# [Infographic]      18
#                  ...
# [NYTimes]           1
# [NLG]               1
# [NIST]              1
# [NEW]               1
# [yourtube]          1
# Name: count, Length: 445, dtype: int64
