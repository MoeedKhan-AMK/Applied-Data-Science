# %%
import pandas as pd

# %%
df_2015 = pd.read_csv('../Dataset/World_Happiness_2015.csv')
df_2016 = pd.read_csv('../Dataset/World_Happiness_2016.csv')
df_2017 = pd.read_csv('../Dataset/World_Happiness_2017.csv')

# %%
df_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
df_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
df_2015["Year"] = 2015
df_2016["Year"] = 2016
df_2017["Year"] = 2017

# %%
three_2015 = df_2015[['Country','Happiness Score', 'Year']].head(3)
three_2016 = df_2016[['Country','Happiness Score', 'Year']].head(3)
# three_2016 = df_2016[['Country','Happiness Score', 'Year']].iloc[1:4]

# %%
three_2015
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015

# %%
three_2016
# Out:
#        Country  Happiness Score  Year
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016
# 3       Norway            7.498  2016

# %%
sample = pd.concat([three_2015,three_2016], axis=0)
sample
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016
# 3       Norway            7.498  2016

# %%
sample.loc[0]
# Out:
# Country            Switzerland
# Happiness Score          7.587
# Year                      2015
# Name: 0, dtype: object

# %%
sample.iloc[0]
# Out:
# Country            Switzerland
# Happiness Score          7.587
# Year                      2015
# Name: 0, dtype: object

# %%
three_2016 = df_2016[['Country','Happiness Score', 'Year']].iloc[1:4]

# %%
concatenation = pd.concat([three_2015,three_2016], axis=0)
concatenation
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 1  Switzerland            7.509  2016
# 2      Iceland            7.501  2016
# 3       Norway            7.498  2016

# %%
concatenation.reset_index(drop=True)
# Out:
#        Country  Happiness Score  Year
# 0  Switzerland            7.587  2015
# 1      Iceland            7.561  2015
# 2      Denmark            7.527  2015
# 3  Switzerland            7.509  2016
# 4      Iceland            7.501  2016
# 5       Norway            7.498  2016

# %%
concatenation = pd.concat([three_2015,three_2016], axis=1)
concatenation
# Out:
#        Country  Happiness Score    Year      Country  Happiness Score    Year
# 0  Switzerland            7.587  2015.0          NaN              NaN     NaN
# 1      Iceland            7.561  2015.0  Switzerland            7.509  2016.0
# 2      Denmark            7.527  2015.0      Iceland            7.501  2016.0
# 3          NaN              NaN     NaN       Norway            7.498  2016.0

# %%
three_2015.rename({"Country":"cty"}, axis=1, inplace=True)

# %%
pd.merge(three_2015, three_2016, left_on='cty', right_on='Country', how='outer' )
# Out:
#            cty  Happiness Score_x  Year_x      Country  Happiness Score_y  \
# 0      Denmark              7.527  2015.0          NaN                NaN
# 1      Iceland              7.561  2015.0      Iceland              7.501
# 2          NaN                NaN     NaN       Norway              7.498
# 3  Switzerland              7.587  2015.0  Switzerland              7.509
#
#    Year_y
# 0     NaN
# 1  2016.0
# 2  2016.0
# 3  2016.0

# %%
df_2017[df_2017["Country"] == "Pakistan"]
# Out:
#      Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 79  Pakistan              80            5.269      5.359984     5.178016
#
#     Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 79                  0.726884  0.672691                  0.402048  0.235215
#
#     Generosity  Trust..Government.Corruption.  Dystopia.Residual  Year
# 79    0.315446                       0.124348           2.792489  2017

# %%
df_2016[df_2016["Country"] == "Pakistan"]
# Out:
#      Country         Region  Happiness Rank  Happiness Score  \
# 91  Pakistan  Southern Asia              92            5.132
#
#     Lower Confidence Interval  Upper Confidence Interval  \
# 91                      5.038                      5.226
#
#     Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 91                   0.68816  0.26135                   0.40306  0.14622
#
#     Trust (Government Corruption)  Generosity  Dystopia Residual  Year
# 91                         0.1388     0.31185            3.18286  2016

# %%
# df_2015[df_2015["cty"] == "Pakistan"]
